# %%
import pandas as pd

books = pd.read_csv("books_with_categories.csv")

# %%
from transformers import pipeline
classifier = pipeline("text-classification",
                      model="j-hartmann/emotion-english-distilroberta-base",
                      top_k = None,
                      device = 0)
classifier("I love this!")
# Out:
# Device set to use cuda:0
# [[{'label': 'joy', 'score': 0.9771687984466553},
#   {'label': 'surprise', 'score': 0.008528676815330982},
#   {'label': 'neutral', 'score': 0.005764597095549107},
#   {'label': 'anger', 'score': 0.004419785924255848},
#   {'label': 'sadness', 'score': 0.002092393347993493},
#   {'label': 'disgust', 'score': 0.0016119939973577857},
#   {'label': 'fear', 'score': 0.0004138521908316761}]]

# %%
books["description"][0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.'

# %%
classifier(books["description"][0])
# Out:
# [[{'label': 'fear', 'score': 0.6548426151275635},
#   {'label': 'neutral', 'score': 0.16985122859477997},
#   {'label': 'sadness', 'score': 0.11640840768814087},
#   {'label': 'surprise', 'score': 0.020700659602880478},
#   {'label': 'disgust', 'score': 0.019100675359368324},
#   {'label': 'joy', 'score': 0.015161176212131977},
#   {'label': 'anger', 'score': 0.003935147076845169}]]

# %%
classifier(books["description"][0].split("."))
# Out:
# [[{'label': 'surprise', 'score': 0.7296030521392822},
#   {'label': 'neutral', 'score': 0.14038562774658203},
#   {'label': 'fear', 'score': 0.06816206127405167},
#   {'label': 'joy', 'score': 0.047942306846380234},
#   {'label': 'anger', 'score': 0.009156343527138233},
#   {'label': 'disgust', 'score': 0.0026284714695066214},
#   {'label': 'sadness', 'score': 0.0021221593488007784}],
#  [{'label': 'neutral', 'score': 0.449370801448822},
#   {'label': 'disgust', 'score': 0.27359169721603394},
#   {'label': 'joy', 'score': 0.10908278822898865},
#   {'label': 'sadness', 'score': 0.09362722933292389},
#   {'label': 'anger', 'score': 0.04047833010554314},
#   {'label': 'surprise', 'score': 0.026970194652676582},
#   {'label': 'fear', 'score': 0.006879061926156282}],
#  [{'label': 'neutral', 'score': 0.6462165713310242},
#   {'label': 'sadness', 'score': 0.24273282289505005},
#   {'label': 'disgust', 'score': 0.04342266544699669},
#   {'label': 'surprise', 'score': 0.028300542384386063},
#   {'label': 'joy', 'score': 0.014211447909474373},
#   {'label': 'fear', 'score': 0.014084095135331154},
#   {'label': 'anger', 'score': 0.01103188656270504}],
#  [{'label': 'fear', 'score': 0.9281679391860962},
#   {'label': 'anger', 'score': 0.03219098970293999},
#   {'label': 'neutral', 'score': 0.01280872244387865},
#   {'label': 'sadness', 'score': 0.00875688437372446},
#   {'label': 'surprise', 'score': 0.00859795045107603},
#   {'label': 'disgust', 'score': 0.008431856520473957},
#   {'label': 'joy', 'score': 0.0010455818846821785}],
#  [{'label': 'sadness', 'score': 0.9671575427055359},
#   {'label': 'neutral', 'score': 0.015104170888662338},
#   {'label': 'disgust', 'score': 0.006480604875832796},
#   {'label': 'fear', 'score': 0.005393994972109795},
#   {'label': 'surprise', 'score': 0.0022869440726935863},
#   {'label': 'anger', 'score': 0.0018428920302540064},
#   {'label': 'joy', 'score': 0.0017338789766654372}],
#  [{'label': 'joy', 'score': 0.9327967762947083},
#   {'label': 'disgust', 'score': 0.037718042731285095},
#   {'label': 'neutral', 'score': 0.01589200086891651},
#   {'label': 'sadness', 'score': 0.006444561295211315},
#   {'label': 'anger', 'score': 0.0050250450149178505},
#   {'label': 'surprise', 'score': 0.0015812111087143421},
#   {'label': 'fear', 'score': 0.0005423118709586561}],
#  [{'label': 'joy', 'score': 0.6528709530830383},
#   {'label': 'neutral', 'score': 0.25427451729774475},
#   {'label': 'surprise', 'score': 0.06808305531740189},
#   {'label': 'sadness', 'score': 0.00990897323936224},
#   {'label': 'disgust', 'score': 0.006512202322483063},
#   {'label': 'anger', 'score': 0.004821309819817543},
#   {'label': 'fear', 'score': 0.003529011271893978}],
#  [{'label': 'neutral', 'score': 0.5494765043258667},
#   {'label': 'sadness', 'score': 0.1116902083158493},
#   {'label': 'disgust', 'score': 0.10400675237178802},
#   {'label': 'surprise', 'score': 0.07876554131507874},
#   {'label': 'anger', 'score': 0.06413368880748749},
#   {'label': 'fear', 'score': 0.051362842321395874},
#   {'label': 'joy', 'score': 0.04056443274021149}]]

# %%
sentences = books["description"][0].split(". ")
predictions = classifier(sentences)

# %%
sentences[0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives'

# %%
predictions[0]
# Out:
# [{'label': 'surprise', 'score': 0.7296030521392822},
#  {'label': 'neutral', 'score': 0.14038562774658203},
#  {'label': 'fear', 'score': 0.06816206127405167},
#  {'label': 'joy', 'score': 0.047942306846380234},
#  {'label': 'anger', 'score': 0.009156343527138233},
#  {'label': 'disgust', 'score': 0.0026284714695066214},
#  {'label': 'sadness', 'score': 0.0021221593488007784}]

# %%
sentences[4]
# Out:
# 'He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption'

# %%
predictions[4]
# Out:
# [{'label': 'sadness', 'score': 0.9560651183128357},
#  {'label': 'neutral', 'score': 0.021593960002064705},
#  {'label': 'disgust', 'score': 0.009161853231489658},
#  {'label': 'fear', 'score': 0.006611271295696497},
#  {'label': 'surprise', 'score': 0.002416068920865655},
#  {'label': 'anger', 'score': 0.0021669939160346985},
#  {'label': 'joy', 'score': 0.0019846935756504536}]

# %%
predictions
# Out:
# [[{'label': 'surprise', 'score': 0.7296030521392822},
#   {'label': 'neutral', 'score': 0.14038562774658203},
#   {'label': 'fear', 'score': 0.06816206127405167},
#   {'label': 'joy', 'score': 0.047942306846380234},
#   {'label': 'anger', 'score': 0.009156343527138233},
#   {'label': 'disgust', 'score': 0.0026284714695066214},
#   {'label': 'sadness', 'score': 0.0021221593488007784}],
#  [{'label': 'neutral', 'score': 0.46624991297721863},
#   {'label': 'disgust', 'score': 0.3382393419742584},
#   {'label': 'joy', 'score': 0.08201279491186142},
#   {'label': 'sadness', 'score': 0.06111669912934303},
#   {'label': 'anger', 'score': 0.029641354456543922},
#   {'label': 'surprise', 'score': 0.01796882040798664},
#   {'label': 'fear', 'score': 0.004771150648593903}],
#  [{'label': 'neutral', 'score': 0.6978471875190735},
#   {'label': 'sadness', 'score': 0.20104166865348816},
#   {'label': 'disgust', 'score': 0.03659280389547348},
#   {'label': 'surprise', 'score': 0.0294979065656662},
#   {'label': 'joy', 'score': 0.012942754663527012},
#   {'label': 'fear', 'score': 0.012581017799675465},
#   {'label': 'anger', 'score': 0.009496768936514854}],
#  [{'label': 'fear', 'score': 0.9839729070663452},
#   {'label': 'neutral', 'score': 0.004363968037068844},
#   {'label': 'sadness', 'score': 0.004239335656166077},
#   {'label': 'anger', 'score': 0.0027069784700870514},
#   {'label': 'surprise', 'score': 0.002331698313355446},
#   {'label': 'disgust', 'score': 0.0017947576707229018},
#   {'label': 'joy', 'score': 0.0005904830759391189}],
#  [{'label': 'sadness', 'score': 0.9560651183128357},
#   {'label': 'neutral', 'score': 0.021593960002064705},
#   {'label': 'disgust', 'score': 0.009161853231489658},
#   {'label': 'fear', 'score': 0.006611271295696497},
#   {'label': 'surprise', 'score': 0.002416068920865655},
#   {'label': 'anger', 'score': 0.0021669939160346985},
#   {'label': 'joy', 'score': 0.0019846935756504536}],
#  [{'label': 'joy', 'score': 0.9490266442298889},
#   {'label': 'disgust', 'score': 0.025817472487688065},
#   {'label': 'neutral', 'score': 0.01415327936410904},
#   {'label': 'sadness', 'score': 0.005034770350903273},
#   {'label': 'anger', 'score': 0.004016013815999031},
#   {'label': 'surprise', 'score': 0.0014610533835366368},
#   {'label': 'fear', 'score': 0.0004908588016405702}],
#  [{'label': 'joy', 'score': 0.6122128367424011},
#   {'label': 'neutral', 'score': 0.31070128083229065},
#   {'label': 'surprise', 'score': 0.04584863409399986},
#   {'label': 'disgust', 'score': 0.01422712579369545},
#   {'label': 'sadness', 'score': 0.009234621189534664},
#   {'label': 'anger', 'score': 0.004417263437062502},
#   {'label': 'fear', 'score': 0.0033582246396690607}]]

# %%
sorted(predictions[0], key=lambda x: x["label"])
# Out:
# [{'label': 'anger', 'score': 0.009156343527138233},
#  {'label': 'disgust', 'score': 0.0026284714695066214},
#  {'label': 'fear', 'score': 0.06816206127405167},
#  {'label': 'joy', 'score': 0.047942306846380234},
#  {'label': 'neutral', 'score': 0.14038562774658203},
#  {'label': 'sadness', 'score': 0.0021221593488007784},
#  {'label': 'surprise', 'score': 0.7296030521392822}]

# %%
import numpy as np

emotion_labels = ["anger", "disgust", "fear", "joy", "neutral", "sadness", "surprise"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

def calculate_max_emotion_scores(predictions):
    per_emotion_scores = {label: [] for label in emotion_labels}
    for prediction in predictions:
        sorted_predictions = sorted(prediction, key=lambda x: x["label"])
        for index, label in enumerate(emotion_labels):
            per_emotion_scores[label].append(sorted_predictions[index]["score"])
    return {label : np.max(scores) for label, scores in per_emotion_scores.items()}

# %%
for i in range(10):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %%
emotion_scores
# Out:
# {'anger': [np.float64(0.06413368880748749),
#   np.float64(0.6126187443733215),
#   np.float64(0.06413368880748749),
#   np.float64(0.351483017206192),
#   np.float64(0.0814124196767807),
#   np.float64(0.2322247326374054),
#   np.float64(0.5381835699081421),
#   np.float64(0.06413368880748749),
#   np.float64(0.30067020654678345),
#   np.float64(0.06413368880748749)],
#  'disgust': [np.float64(0.27359169721603394),
#   np.float64(0.34828490018844604),
#   np.float64(0.10400675237178802),
#   np.float64(0.1507224589586258),
#   np.float64(0.18449519574642181),
#   np.float64(0.7271749973297119),
#   np.float64(0.15585504472255707),
#   np.float64(0.10400675237178802),
#   np.float64(0.2794809937477112),
#   np.float64(0.17792734503746033)],
#  'fear': [np.float64(0.9281679391860962),
#   np.float64(0.942527711391449),
#   np.float64(0.9723208546638489),
#   np.float64(0.3607073426246643),
#   np.float64(0.09504338353872299),
#   np.float64(0.051362842321395874),
#   np.float64(0.7474281787872314),
#   np.float64(0.40449562668800354),
#   np.float64(0.9155241250991821),
#   np.float64(0.051362842321395874)],
#  'joy': [np.float64(0.9327967762947083),
#   np.float64(0.7044206261634827),
#   np.float64(0.7672370672225952),
#   np.float64(0.25188079476356506),
#   np.float64(0.04056443274021149),
#   np.float64(0.043375879526138306),
#   np.float64(0.8725650310516357),
#   np.float64(0.04056443274021149),
#   np.float64(0.04056443274021149),
#   np.float64(0.04056443274021149)],
#  'neutral': [np.float64(0.6462165713310242),
#   np.float64(0.8879395127296448),
#   np.float64(0.5494765043258667),
#   np.float64(0.7326856255531311),
#   np.float64(0.8843896389007568),
#   np.float64(0.6213924288749695),
#   np.float64(0.7121944427490234),
#   np.float64(0.5494765043258667),
#   np.float64(0.8402894735336304),
#   np.float64(0.8603722453117371)],
#  'sadness': [np.float64(0.9671575427055359),
#   np.float64(0.1116902083158493),
#   np.float64(0.1116902083158493),
#   np.float64(0.1116902083158493),
#   np.float64(0.47588053345680237),
#   np.float64(0.1116902083158493),
#   np.float64(0.40800055861473083),
#   np.float64(0.8202821612358093),
#   np.float64(0.35446032881736755),
#   np.float64(0.1116902083158493)],
#  'surprise': [np.float64(0.7296030521392822),
#   np.float64(0.25254493951797485),
#   np.float64(0.07876554131507874),
#   np.float64(0.07876554131507874),
#   np.float64(0.07876554131507874),
#   np.float64(0.2719029486179352),
#   np.float64(0.07876554131507874),
#   np.float64(0.23448750376701355),
#   np.float64(0.13561390340328217),
#   np.float64(0.07876554131507874)]}

# %%
from tqdm import tqdm
emotion_labels = ["anger", "disgust", "fear", "joy", "neutral", "sadness", "surprise"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

for i in tqdm(range(len(books))):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])
# Out:
# 100%|██████████| 5197/5197 [01:48<00:00, 47.76it/s]

# %%
emotions_df = pd.DataFrame(emotion_scores)
emotions_df["isbn13"] = isbn

# %%
emotions_df
# Out:
#          anger   disgust      fear       joy   neutral   sadness  surprise  \
# 0     0.064134  0.273592  0.928168  0.932797  0.646217  0.967158  0.729603
# 1     0.612619  0.348285  0.942528  0.704421  0.887940  0.111690  0.252545
# 2     0.064134  0.104007  0.972321  0.767237  0.549477  0.111690  0.078766
# 3     0.351483  0.150722  0.360707  0.251881  0.732686  0.111690  0.078766
# 4     0.081412  0.184495  0.095043  0.040564  0.884390  0.475881  0.078766
# ...        ...       ...       ...       ...       ...       ...       ...
# 5192  0.148209  0.030643  0.919165  0.255169  0.853721  0.980877  0.030656
# 5193  0.064134  0.114383  0.051363  0.400263  0.883199  0.111690  0.227764
# 5194  0.009997  0.009929  0.339218  0.947779  0.375755  0.066685  0.057625
# 5195  0.064134  0.104007  0.459270  0.759455  0.951104  0.368111  0.078766
# 5196  0.064134  0.104007  0.051363  0.958549  0.915193  0.111690  0.078766
#
#              isbn13
# 0     9780002005883
# 1     9780002261982
# 2     9780006178736
# 3     9780006280897
# 4     9780006280934
# ...             ...
# 5192  9788172235222
# 5193  9788173031014
# 5194  9788179921623
# 5195  9788185300535
# 5196  9789027712059
#
# [5197 rows x 8 columns]

# %%
books = pd.merge(books, emotions_df, on="isbn13")

# %%
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195                                          I Am that
# 5196                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5192                              Nayantara Sahgal
# 5193                                 Hermann Hesse
# 5194                                  Robin Sharma
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5196                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5192        Indic fiction (English)
# 5193              Adventure stories
# 5194               Health & Fitness
# 5195                     Philosophy
# 5196                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ...  \
# 0               3.85      247.0  ...
# 1               3.83      241.0  ...
# 2               3.93      512.0  ...
# 3               4.15      170.0  ...
# 4               4.09      176.0  ...
# ...              ...        ...  ...
# 5192            2.93      324.0  ...
# 5193            3.70      175.0  ...
# 5194            3.82      198.0  ...
# 5195            4.51      531.0  ...
# 5196            0.00      210.0  ...
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195     I Am that: Talks with Sri Nisargadatta Maharaj
# 5196                           The Berlin Phenomenology
#
#                                      tagged_description simple_categories  \
# 0     9780002005883 A NOVEL THAT READERS and critics...           Fiction
# 1     9780002261982 A new 'Christie for Christmas' -...           Fiction
# 2     9780006178736 A memorable, mesmerizing heroine...           Fiction
# 3     9780006280897 Lewis' work on the nature of lov...           Fiction
# 4     9780006280934 "In The Problem of Pain, C.S. Le...           Fiction
# ...                                                 ...               ...
# 5192  9788172235222 On A Train Journey Home To North...           Fiction
# 5193  9788173031014 This book tells the tale of a ma...           Fiction
# 5194  9788179921623 Wisdom to Create a Life of Passi...           Fiction
# 5195  9788185300535 This collection of the timeless ...        Nonfiction
# 5196  9789027712059 Since the three volume edition o...        Nonfiction
#
#          anger   disgust      fear       joy   neutral   sadness  surprise
# 0     0.064134  0.273592  0.928168  0.932797  0.646217  0.967158  0.729603
# 1     0.612619  0.348285  0.942528  0.704421  0.887940  0.111690  0.252545
# 2     0.064134  0.104007  0.972321  0.767237  0.549477  0.111690  0.078766
# 3     0.351483  0.150722  0.360707  0.251881  0.732686  0.111690  0.078766
# 4     0.081412  0.184495  0.095043  0.040564  0.884390  0.475881  0.078766
# ...        ...       ...       ...       ...       ...       ...       ...
# 5192  0.148209  0.030643  0.919165  0.255169  0.853721  0.980877  0.030656
# 5193  0.064134  0.114383  0.051363  0.400263  0.883199  0.111690  0.227764
# 5194  0.009997  0.009929  0.339218  0.947779  0.375755  0.066685  0.057625
# 5195  0.064134  0.104007  0.459270  0.759455  0.951104  0.368111  0.078766
# 5196  0.064134  0.104007  0.051363  0.958549  0.915193  0.111690  0.078766
#
# [5197 rows x 21 columns]

# %%
books.to_csv("books_with_emotions.csv", index=False)
